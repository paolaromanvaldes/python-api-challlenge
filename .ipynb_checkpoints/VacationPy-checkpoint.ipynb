# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests
import json

# Import API key
from api_keys import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0  cabo san lucas  22.8909 -109.9124     75.76        55         100
# 1        1    invercargill -46.4000  168.3500     54.01        85          29
# 2        2   blackmans bay -43.0167  147.3167     64.53        82          83
# 3        3         college  64.8569 -147.8028     11.07        85          75
# 4        4           yaren  -0.5472  166.9160     82.53        81          76
#
#    Wind Speed Country        Date
# 0        1.01      MX  1705423829
# 1        3.00      NZ  1705424002
# 2       10.33      AU  1705424003
# 3        3.44      US  1705424003
# 4       11.18      NR  1705424004

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
map_1 = city_data_df.hvplot.points('Lng','Lat', geo=True, tiles = 'OSM', frame_width = 700, frame_height = 500, color='City', alpha= 0.5, s='Humidity', scale= 0.8)

# Display the map
map_1
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
ideal_conditions = ((city_data_df['Max Temp'] > 60) & (city_data_df['Max Temp'] < 90) & (city_data_df['Wind Speed'] < 6) & (city_data_df['Cloudiness'] < 35) & (city_data_df['Humidity'] < 50))
filtered_cities = city_data_df[ideal_conditions]
# Drop any rows with null values
filtered_cities.dropna()

# Display sample data
filtered_cities
# Out:
#      City_ID               City      Lat       Lng  Max Temp  Humidity  \
# 154      154             illizi  26.4833    8.4667     75.00        10
# 168      168             halwan  29.8414   31.3008     63.36        35
# 190      190          bhatapara  21.7333   81.9333     65.41        41
# 213      213           am timan  11.0297   20.2827     81.72        13
# 322      322  puerto el triunfo  13.2833  -88.5500     88.65        41
# 405      405        tamanrasset  22.7850    5.5228     75.11         6
# 438      438         san julian  21.0167 -102.1667     68.27        21
# 476      476           valdivia -39.8142  -73.2459     69.89        38
# 486      486    heroica guaymas  27.9333 -110.9000     66.45        37
# 490      490            tilcara -23.5776  -65.3509     74.08        38
#
#      Cloudiness  Wind Speed Country        Date
# 154           6        5.21      DZ  1705424094
# 168          11        4.52      EG  1705424018
# ...

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
hotel_df = filtered_cities.iloc[:,[1,8,2,3,5]].copy()
hotel_df['Hotel Name']=''
# Display sample data
hotel_df
# Out:
#                   City Country      Lat       Lng  Humidity Hotel Name
# 154             illizi      DZ  26.4833    8.4667        10
# 168             halwan      EG  29.8414   31.3008        35
# 190          bhatapara      IN  21.7333   81.9333        41
# 213           am timan      TD  11.0297   20.2827        13
# 322  puerto el triunfo      SV  13.2833  -88.5500        41
# 405        tamanrasset      DZ  22.7850    5.5228         6
# 438         san julian      MX  21.0167 -102.1667        21
# 476           valdivia      CL -39.8142  -73.2459        38
# 486    heroica guaymas      MX  27.9333 -110.9000        37
# 490            tilcara      AR -23.5776  -65.3509        38

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 50000
prms = {'categories':'accommodation.hotel',\
         'filter':'',\
         'bias':'',\
         'apiKey':geoapify_key,\
         'limit':1}

# Print a message to follow up the hotel search
print("Starting Hotel Search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    lon = row['Lng']
    lat = row['Lat']
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f'circle:{lon},{lat},{radius}'
    params["bias"] = f'proximity:{lon},{lat}'
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"

    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
#         # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
    #     # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# # Display sample data
hotel_df
# Out:
# Starting Hotel Search
# illizi - nearest hotel: بوناقة
# halwan - nearest hotel: شهاب
# bhatapara - nearest hotel: No hotel found
# am timan - nearest hotel: Nimla
# puerto el triunfo - nearest hotel: Motel Jardín
# tamanrasset - nearest hotel: فندق الأمان
# san julian - nearest hotel: No hotel found
# valdivia - nearest hotel: Esmeralda
# heroica guaymas - nearest hotel: Hotel Playa de Cortéz
# tilcara - nearest hotel: Casa Colorada - Hotel de Montaña
#                   City Country      Lat       Lng  Humidity  \
# 154             illizi      DZ  26.4833    8.4667        10
# 168             halwan      EG  29.8414   31.3008        35
# 190          bhatapara      IN  21.7333   81.9333        41
# 213           am timan      TD  11.0297   20.2827        13
# 322  puerto el triunfo      SV  13.2833  -88.5500        41
# 405        tamanrasset      DZ  22.7850    5.5228         6
# 438         san julian      MX  21.0167 -102.1667        21
# ...

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# Configure the map plot
map_2 = hotel_df.hvplot.points('Lng', 'Lat', geo=True, tiles = 'OSM', frame_width = 700, frame_height = 500, color='City',alpha=0.6,hover=True,hover_cols='all',use_index=False,s='Humidity',scale= 1.2)

# Display the map
map_2
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Country,Hotel Name)
