# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 623

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = f"http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID={weather_api_key}"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
       # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        
        
        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | cabo san lucas
# Processing Record 2 of Set 1 | invercargill
# Processing Record 3 of Set 1 | blackmans bay
# Processing Record 4 of Set 1 | college
# Processing Record 5 of Set 1 | yaren
# Processing Record 6 of Set 1 | lebu
# Processing Record 7 of Set 1 | labrador city
# Processing Record 8 of Set 1 | karatuzskoye
# Processing Record 9 of Set 1 | antofagasta
# Processing Record 10 of Set 1 | sisimiut
# Processing Record 11 of Set 1 | pariaman
# Processing Record 12 of Set 1 | kharkhorin
# Processing Record 13 of Set 1 | margaret river
# Processing Record 14 of Set 1 | tolanaro
# Processing Record 15 of Set 1 | marang
# Processing Record 16 of Set 1 | igarka
# Processing Record 17 of Set 1 | vila velha
# Processing Record 18 of Set 1 | al kharijah
# Processing Record 19 of Set 1 | belgrade
# Processing Record 20 of Set 1 | taiohae
# City not found. Skipping...
# ...

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          591
# Lat           591
# Lng           591
# Max Temp      591
# Humidity      591
# Cloudiness    591
# Wind Speed    591
# Country       591
# Date          591
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  cabo san lucas  22.8909 -109.9124     75.76        55         100
# 1    invercargill -46.4000  168.3500     54.01        85          29
# 2   blackmans bay -43.0167  147.3167     64.53        82          83
# 3         college  64.8569 -147.8028     11.07        85          75
# 4           yaren  -0.5472  166.9160     82.53        81          76
#
#    Wind Speed Country        Date
# 0        1.01      MX  1705423829
# 1        3.00      NZ  1705424002
# 2       10.33      AU  1705424003
# 3        3.44      US  1705424003
# 4       11.18      NR  1705424004

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        cabo san lucas  22.8909 -109.9124     75.76        55         100
# 1          invercargill -46.4000  168.3500     54.01        85          29
# 2         blackmans bay -43.0167  147.3167     64.53        82          83
# 3               college  64.8569 -147.8028     11.07        85          75
# 4                 yaren  -0.5472  166.9160     82.53        81          76
#
#          Wind Speed Country        Date
# City_ID
# 0              1.01      MX  1705423829
# 1              3.00      NZ  1705424002
# 2             10.33      AU  1705424003
# 3              3.44      US  1705424003
# 4             11.18      NR  1705424004

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df['Lat'],city_data_df['Max Temp'], edgecolor="black", linewidth=1, marker="o", alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude Vs. Max Temperature(%s)" % time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df['Lat'],city_data_df['Humidity'], edgecolor="black", linewidth=1, marker="o", alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude Vs. Humidity(%s)" % time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df['Lat'],city_data_df['Cloudiness'], edgecolor="black", linewidth=1, marker="o", alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude Vs.Cloudiness(%s)" % time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df['Lat'],city_data_df['Wind Speed'], edgecolor="black", linewidth=1, marker="o", alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude Vs. Wind Speed(%s)" % time.strftime("%x"))
plt.ylabel("Wind Speed (m/s)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def linear_regression(x,y,name,lbl,hemishpere):
    (slope,intercept,rvalue,pvalue,stderror)=linregress(x,y)
    reg_values= x*slope + intercept
    plt.plot(x,reg_values,color='r')
    plt.title(f'Latitude vs. {lbl} - {hemishpere}')
    plt.xlabel('Latitude')
    plt.ylabel(lbl)
    line_eq = f'y = {(round(slope,2))}x + {(round(intercept,2))}'
    if hemisphere == "Northern Hemisphere":
        coord = (0,25)
    else:
        coord = (-20, 40)
    plt.annotate(line_eq, coord,fontsize=12,color="red")
    plt.savefig(f"output_data/LinearRegresion_{name}.png")
    print(f'The r-value is: {rvalue}')

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
n_hemisphere_df = city_data_df.loc[city_data_df['Lat']>= 0,:]

# Display sample data
n_hemisphere_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        cabo san lucas  22.8909 -109.9124     75.76        55         100
# 3               college  64.8569 -147.8028     11.07        85          75
# 6         labrador city  52.9463  -66.9114     -2.29        84          20
# 7          karatuzskoye  53.6072   92.8667    -19.30        99          19
# 9              sisimiut  66.9395  -53.6735     27.52        89          72
#
#          Wind Speed Country        Date
# City_ID
# 0              1.01      MX  1705423829
# 3              3.44      US  1705424003
# 6              0.00      CA  1705424005
# 7              0.47      RU  1705424006
# 9              5.35      GL  1705424007

# %%
# Createa DataFrame with the Southern Hemisphere data (Latitude < 0)
s_hemisphere_df = city_data_df.loc[city_data_df['Lat']<= 0,:]
 
# Display sample data
s_hemisphere_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1         invercargill -46.4000  168.3500     54.01        85          29
# 2        blackmans bay -43.0167  147.3167     64.53        82          83
# 4                yaren  -0.5472  166.9160     82.53        81          76
# 5                 lebu -37.6167  -73.6500     62.92        73           1
# 8          antofagasta -23.6500  -70.4000     72.68        72          49
#
#          Wind Speed Country        Date
# City_ID
# 1              3.00      NZ  1705424002
# 2             10.33      AU  1705424003
# 4             11.18      NR  1705424004
# 5             17.92      CL  1705424004
# 8             10.76      CL  1705424006

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x = n_hemisphere_df['Lat']
y = n_hemisphere_df['Max Temp']
name = 'NorthernHemisphereLatVsMaxTemp'
lbl = 'Maximum Temperature C°'
hemisphere = 'Northern Hemisphere'
linear_regression(x,y,name,lbl,hemisphere)


plt.scatter(n_hemisphere_df['Lat'],n_hemisphere_df['Max Temp'], marker='o')
# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
plt.title("Latitude vs. Temperature in Northern Hemisphere")

plt.show()
# Out:
# The r-value is: -0.875879244226933

# %%
# Linear regression on Southern Hemisphere
x = s_hemisphere_df['Lat']
y = s_hemisphere_df['Max Temp']
name = 'SouthernHemisphereLatVsMaxTemp'
lbl = 'Maximum Temperature C°'
hemisphere = 'Southern Hemisphere'
linear_regression(x,y,name,lbl,hemisphere)


plt.scatter(s_hemisphere_df['Lat'],s_hemisphere_df['Max Temp'], marker='o')
# Incorporate the other graph properties

plt.xlabel("Latitude")
plt.ylabel("Max Temp")
plt.title("Latitude vs. Temperature in Southern Hemisphere")
# Out:
# The r-value is: 0.6353799172919605
# Text(0.5, 1.0, 'Latitude vs. Temperature in Southern Hemisphere')

# %% [markdown]
# **Discussion about the linear relationship:** Negative r value of .87 means that there is a very strong negative correlation between Northern Hemisphere and Max Temp and  r value of .63 means that there is a strong positive correlation between Southern Hemisphere and Max Temp

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x = n_hemisphere_df['Lat']
y = n_hemisphere_df['Humidity']
name = 'NorthernHemisphereLatVsHumidity'
lbl = 'Humidity %'
hemisphere = 'Northern Hemisphere'
linear_regression(x,y,name,lbl,hemisphere)
plt.scatter(n_hemisphere_df['Lat'],n_hemisphere_df['Humidity'], marker='o')
plt.show()
# Out:
# The r-value is: 0.4451080737082505

# %%
# Southern Hemisphere
x = s_hemisphere_df['Lat']
y = s_hemisphere_df['Humidity']
name = 'SouthernHemisphereLatVsHumidity'
lbl = 'Humidity %'
hemisphere = 'Southern Hemisphere'
linear_regression(x,y,name,lbl,hemisphere)
plt.scatter(s_hemisphere_df['Lat'],s_hemisphere_df['Humidity'], marker='o')
plt.show()
# Out:
# The r-value is: -0.008718075073302451

# %% [markdown]
# **Discussion about the linear relationship:** Negative r value of .008 means that there is a very low negative correlation between Southern Hemisphere and Humidity percentage and r value of .44 means that there is a medium positive correlation between Northern Hemisphere and Humidity

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x = n_hemisphere_df['Lat']
y = n_hemisphere_df['Cloudiness']
name = 'NorthernHemisphereLatVsCloudiness'
lbl = 'Cloudiness'
hemisphere = 'Northern Hemisphere'
linear_regression(x,y,name,lbl,hemisphere)
plt.scatter(n_hemisphere_df['Lat'],n_hemisphere_df['Cloudiness'], marker='o')
plt.show()
# Out:
# The r-value is: 0.15901064338053514

# %%
# Southern Hemisphere
x = s_hemisphere_df['Lat']
y = s_hemisphere_df['Cloudiness']
name = 'SouthernHemisphereLatVsCloudiness'
lbl = 'Cloudiness'
hemisphere = 'Southern Hemisphere'
linear_regression(x,y,name,lbl,hemisphere)
plt.scatter(s_hemisphere_df['Lat'],s_hemisphere_df['Cloudiness'], marker='o')
plt.show()
# Out:
# The r-value is: 0.21026213257937462

# %% [markdown]
# **Discussion about the linear relationship:**  r value of .21 means that there is a low correlation between Southern Hemisphere and Cloudiness percentage and r value of .15 means that there is a very low positive correlation between Northern Hemisphere and Cloudiness

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x = n_hemisphere_df['Lat']
y = n_hemisphere_df['Wind Speed']
name = 'NorthernHemisphereLatVsWindSpeed'
lbl = 'Wind Speed'
hemisphere = 'Northern Hemisphere'
linear_regression(x,y,name,lbl,hemisphere)
plt.scatter(n_hemisphere_df['Lat'],n_hemisphere_df['Wind Speed'], marker='o')
plt.show()
# Out:
# The r-value is: -0.046703851280971036

# %%
# Southern Hemisphere
x = s_hemisphere_df['Lat']
y = s_hemisphere_df['Wind Speed']
name = 'SouthernHemisphereLatVsWindSpeed'
lbl = 'Wind Speed'
hemisphere = 'Southern Hemisphere'
linear_regression(x,y,name,lbl,hemisphere)
plt.scatter(s_hemisphere_df['Lat'],s_hemisphere_df['Wind Speed'], marker='o')
plt.show()
# Out:
# The r-value is: -0.10665191024767244

# %% [markdown]
# **Discussion about the linear relationship:** a negative correlation for both. a very low correlation of .04 for the northern hemisphere and a very low correlation of .1 for the southern hemisphere
